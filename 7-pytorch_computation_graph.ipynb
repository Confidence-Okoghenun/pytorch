# %%
import torch
import numpy as np
import torch.nn as nn
import hiddenlayer as hl

# %%
W = torch.randn(6)
x = torch.tensor([10.0,10.0,10.0,10.0,10.0,10.0])
b = torch.tensor(3)

# %%
W,x,b
# Out:
# (tensor([-1.5017,  1.0626,  0.8880,  0.0806,  0.1583, -1.3653]),
#  tensor([10., 10., 10., 10., 10., 10.]),
#  tensor(3))

# %%
y = W*x + b
y
# Out:
# tensor([-12.0171,  13.6261,  11.8799,   3.8064,   4.5832, -10.6534])

# %%
W*x
# Out:
# tensor([-15.0171,  10.6261,   8.8799,   0.8064,   1.5832, -13.6534])

# %%
b
# Out:
# tensor(3)

# %%
W1 = torch.tensor(6)
W2 = torch.tensor(6)
W3 = torch.tensor(6)

x1 = torch.tensor([2,2,2])
x2 = torch.tensor([3,3,3])
x3 = torch.tensor([4,4,4])

b = torch.tensor(10)

W1,W2,W3
# Out:
# (tensor(6), tensor(6), tensor(6))

# %%
intermediate_value = W1*x1 + W2*x2
intermediate_value
# Out:
# tensor([30, 30, 30])

# %%
final_value = W1*x1 + W2*x2 + W3*x3 + b
final_value
# Out:
# tensor([64, 64, 64])

# %%
x_train = np.array([[1.7], [2.5], [5.5], [7.9], [8.8], [2.4], [2.4], [8.89], [5], [4.4]], dtype=np.float32)
y_train = np.array([[1.9], [2.68], [4.22], [8.19], [9.69], [3.4], [2.6], [8.8], [5.6], [4.7]], dtype=np.float32)

# %%
X_train = torch.tensor(x_train)
Y_train = torch.tensor(y_train)

X_train.shape
# Out:
# torch.Size([10, 1])

# %%
inp = 1
out = 1
hid = 100

# %%
model1 = torch.nn.Sequential(torch.nn.Linear(inp, hid), torch.nn.Linear(hid, out))
model1
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=100, bias=True)
#   (1): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
hl.build_graph(model1, torch.zeros([10, 1])) #Builds a graph of test data with a 10x1 matrix of zeros

# %%
hl.build_graph(model1, torch.zeros(1)) #build_graph expands visualizations when given small data points ie 1x1 matrix of zeros

# %%
model2 = torch.nn.Sequential(torch.nn.Linear(inp, hid), torch.nn.Linear(hid, hid), torch.nn.Sigmoid(), torch.nn.Linear(hid, out))
model2
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=100, bias=True)
#   (1): Linear(in_features=100, out_features=100, bias=True)
#   (2): Sigmoid()
#   (3): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
hl.build_graph(model2, torch.zeros([10,1]))

# %%
hl.build_graph(model2, torch.zeros(1))
